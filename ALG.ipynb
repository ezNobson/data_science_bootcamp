# %% [markdown]
# <a href="https://colab.research.google.com/github/ezNobson/data_science_bootcamp/blob/arrays/ALG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# Norma wektora

# %%
v1 = np.array([0,4])
v1
# Out:
# array([0, 4])

# %%
np.linalg.norm(v1)
# Out:
# 4.0

# %%
v2=np.array([-1,4,5])
np.linalg.norm(v2)
# Out:
# 6.48074069840786
